# %% [markdown]
# # №1. Найти длину 𝑥 и ширину 𝑦 прямоугольника при заданном периметре 𝑃=144 cм, при которых данный прямоугольник имеет наибольшую площадь 𝑆.

# %% [markdown]
# $x = a$
#
# $y = 72 - a$
#
# $S = a (72 - a) = 72a - a^2$
#
#
# Возмем производную от функции
#
# $S` = (72a - a^2)` = 72 - 2a$
#
# Критических точек нет. Найдем стационарные точки. Приравняв производную нулю, получим:
#
# $72 - 2a = 0$
#
#
# $2a = 72$
#
#
# $a = 36$
#
#
# Точка x=3 соответствует требованию зазания. Заметим, что при $a<36,S′>0$, а при $a>36,S′<0$. Значит точка $a=36$  является точкой максимума функции.
#
# $x = 36$
#
# $y = 72 - 36$
#
# Ответ:
# Так как, периметр прямоугольника составляет 144 см, то  прямоугольник имеет наибольшую площадь S=1296 см2, если его стороны 36 см и  36 см.

# %% [markdown]
# # №2. найти экстремумы функций (если они есть)

# %% [markdown]
# $y = |2x|$
#
# $y = x^3$
#
# $y = e^{3x}$
#
# $y = x^3 - 5x$

# %% [markdown]
# ## Решение

# %% [markdown]
# ### 𝑦=|2𝑥|
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $y^` = |2x|^` = 2 $
#
#
# нет локального экстремума

# %% [markdown]
# ### $y = x^3$
#
#
# ![image.png](data:image/png;base64,...)![image.png]()

# %% [markdown]
# $y^` = x^3` = 3x^2 $
#
# При подставлении любого значения x в функцию  $f(x) = 3x^2$, значение функции всегда будет положительным
#
# А при $x_0 = 0$ производная $f`(x) = 0$ так же будет равна 0, но в критической точке нет максимума или минимума функции.
#
#
# нет локального максимума и минимума

# %% [markdown]
# ### $y = e^{3x}$
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $y` = e^{3x}` = 3*e^{3x}$
#
# Глобальных экстремумов нет

# %% [markdown]
# ### $y = x^3 - 5x$
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $y` = (x^3 - 5x)` = x^3` - 5x` = 3x^2 - 5$
#
# $3x^2 -5 = 0$
#
#
# $3x^2 = 5$
#
# $x^2 = \frac{5}{3}$
#
# $x_1 = \sqrt{\frac{5}{3}}$
#
# $x_2 = -\sqrt{\frac{5}{3}}$
#
#
# $y`` = (x^3 - 5x)`` = x^3`` - 5x`` = 3x^2` - 5` = 6x - 0 = 6x$
#
# $y`` = 6x = 6 * \sqrt{\frac{5}{3}} > 0$ - значит точка  $x = \sqrt{\frac{5}{3}}$ точка минимума функции
#
# $y`` = 6x = 6 (-\sqrt{\frac{5}{3}}) = -6\sqrt{\frac{5}{3}} < 0$ - значит точка  $x = -\sqrt{\frac{5}{3}}$ точка максимума функции
